# %%
import pandas as pd

# %% [markdown]
# ## Load Raw Data To System

# %%
# Data loaded to a variable
sourceData = pd.read_excel(r'C:\Users\hp\Desktop\ML & AL Program Upgrad\Source Files\EDA_Data_Sourcing.xlsx',header=1)

# %%
sourceData.head(10)
# Out:
#    Application ID  No of times 90 DPD or worse in last 6 months  \
# 0       954457215                                             0
# 1       432830445                                             0
# 2       941387308                                             0
# 3       392161677                                             0
# 4       182011211                                             0
# 5       312196805                                             0
# 6       532217204                                             0
# 7        74788849                                             0
# 8       782743811                                             0
# 9        96964957                                             0
#
#    No of times 60 DPD or worse in last 6 months  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# ...
